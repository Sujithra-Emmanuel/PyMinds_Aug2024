# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_excel('V02Max_Combined.xlsx')

# %%
data.head()
# Out:
#    ID     time     RR       VO2  power
# 0  11 -168.600  727.0  0.287147      0
# 1  11 -167.872  728.0  0.287147      0
# 2  11 -167.148  724.0  0.287147      0
# 3  11 -166.484  664.0  0.320580      0
# 4  11 -165.836  648.0  0.320580      0

# %%
# importing excel data
xls = 'V02Max_Combined.xlsx'

# %%
#importing each sheets in to seperate data frame
data_Kayaking = pd.read_excel(xls,sheet_name = 'Kayaking')
data_Kayaking = pd.read_excel(xls,sheet_name = 'Kayaking')
data_Athletes = pd.read_excel(xls, sheet_name = 'Athletes')
data_Triathlon = pd.read_excel(xls,sheet_name =  'Triathlon')
data_Fencing = pd.read_excel(xls,sheet_name =  'Fencing')
# Out:
# C:\Users\Phgan\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\Phgan\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\Phgan\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
data_Kayaking
# Out:
#        ID      time     RR       VO2  power
# 0      11  -168.600  727.0  0.287147      0
# 1      11  -167.872  728.0  0.287147      0
# 2      11  -167.148  724.0  0.287147      0
# 3      11  -166.484  664.0  0.320580      0
# 4      11  -165.836  648.0  0.320580      0
# ...    ..       ...    ...       ...    ...
# 19473  16  1118.404  548.0  0.671957      0
# 19474  16  1118.944  540.0  0.671957      0
# 19475  16  1119.484  540.0  0.671957      0
# 19476  16  1120.016  532.0  0.671957      0
# 19477  16  1120.544  528.0  0.671957      0
#
# [19478 rows x 5 columns]

# %%
data_Athletes.head()
# Out:
#    ID  age  Weight  Height  P_vt1  P_vt2    sport  Gender Ethnicity  \
# 0   1   15    53.7     161     50    140  fencing  Female   African
# 1   2   15    56.2     162     80    127  fencing    Male   African
# 2   3   16    89.9     191    155    300  fencing    Male     White
# 3   4   16    76.5     180    215    275  fencing    Male     White
# 4   5   17    76.4     186    110    172  fencing  Female     White
#
#   First Name Last Name
# 0     Olivia  Martinez
# 1      Ethan  Reynolds
# 2    Jackson    Harper
# 3       Liam   Sanchez
# 4        Ava  Thompson

# %%
data_Triathlon
# Out:
#       ID     time     RR       VO2  power
# 0     17 -182.408  736.0  0.363762      0
# 1     17 -181.672  736.0  0.363762      0
# 2     17 -180.968  704.0  0.363762      0
# 3     17 -180.268  700.0  0.363762      0
# 4     17 -179.616  652.0  0.363762      0
# ...   ..      ...    ...       ...    ...
# 4976  18  947.288  536.0  0.507071      0
# 4977  18  947.816  528.0  0.507071      0
# 4978  18  948.344  528.0  0.507071      0
# 4979  18  948.884  540.0  0.507071      0
# 4980  18  949.424  540.0  0.507071      0
#
# [4981 rows x 5 columns]

# %%
# Check for duplicate rows
data_Kayaking[data_Kayaking.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, time, RR, VO2, power]
# Index: []

# %%
# Check for duplicate rows
data_Triathlon[data_Triathlon.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, time, RR, VO2, power]
# Index: []

# %%
# Check for duplicate rows
data_Fencing[data_Fencing.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, time, RR, VO2, power]
# Index: []

# %%
#merging all the dataframes
merged_df = data_Athletes.merge(data_Kayaking, on='ID', how='left')

# %%
merged_df
# Out:
#        ID  age  Weight  Height  P_vt1  P_vt2      sport  Gender Ethnicity  \
# 0       1   15    53.7     161     50    140    fencing  Female   African
# 1       2   15    56.2     162     80    127    fencing    Male   African
# 2       3   16    89.9     191    155    300    fencing    Male     White
# 3       4   16    76.5     180    215    275    fencing    Male     White
# 4       5   17    76.4     186    110    172    fencing  Female     White
# ...    ..  ...     ...     ...    ...    ...        ...     ...       ...
# 19485  16   16    70.4     182     79    175      kayak    Male    Latino
# 19486  16   16    70.4     182     79    175      kayak    Male    Latino
# 19487  16   16    70.4     182     79    175      kayak    Male    Latino
# 19488  17   12    39.9     156    101    145  triathlon    Male    Latino
# 19489  18   12    39.7     158     65    168  triathlon    Male    Latino
#
#       First Name Last Name      time     RR       VO2  power
# 0         Olivia  Martinez       NaN    NaN       NaN    NaN
# 1          Ethan  Reynolds       NaN    NaN       NaN    NaN
# 2        Jackson    Harper       NaN    NaN       NaN    NaN
# 3           Liam   Sanchez       NaN    NaN       NaN    NaN
# 4            Ava  Thompson       NaN    NaN       NaN    NaN
# ...          ...       ...       ...    ...       ...    ...
# 19485      Logan  Anderson  1119.484  540.0  0.671957    0.0
# 19486      Logan  Anderson  1120.016  532.0  0.671957    0.0
# 19487      Logan  Anderson  1120.544  528.0  0.671957    0.0
# 19488      Lucas    Foster       NaN    NaN       NaN    NaN
# 19489       Owen     Myers       NaN    NaN       NaN    NaN
#
# [19490 rows x 15 columns]

# %%
merged_df = merged_df.merge(data_Triathlon, on='ID', how='left' )

# %%
merged_df
# Out:
#        ID  age  Weight  Height  P_vt1  P_vt2      sport  Gender Ethnicity  \
# 0       1   15    53.7     161     50    140    fencing  Female   African
# 1       2   15    56.2     162     80    127    fencing    Male   African
# 2       3   16    89.9     191    155    300    fencing    Male     White
# 3       4   16    76.5     180    215    275    fencing    Male     White
# 4       5   17    76.4     186    110    172    fencing  Female     White
# ...    ..  ...     ...     ...    ...    ...        ...     ...       ...
# 24464  18   12    39.7     158     65    168  triathlon    Male    Latino
# 24465  18   12    39.7     158     65    168  triathlon    Male    Latino
# 24466  18   12    39.7     158     65    168  triathlon    Male    Latino
# 24467  18   12    39.7     158     65    168  triathlon    Male    Latino
# 24468  18   12    39.7     158     65    168  triathlon    Male    Latino
#
#       First Name Last Name  time_x  RR_x  VO2_x  power_x   time_y   RR_y  \
# 0         Olivia  Martinez     NaN   NaN    NaN      NaN      NaN    NaN
# 1          Ethan  Reynolds     NaN   NaN    NaN      NaN      NaN    NaN
# 2        Jackson    Harper     NaN   NaN    NaN      NaN      NaN    NaN
# 3           Liam   Sanchez     NaN   NaN    NaN      NaN      NaN    NaN
# 4            Ava  Thompson     NaN   NaN    NaN      NaN      NaN    NaN
# ...          ...       ...     ...   ...    ...      ...      ...    ...
# 24464       Owen     Myers     NaN   NaN    NaN      NaN  947.288  536.0
# 24465       Owen     Myers     NaN   NaN    NaN      NaN  947.816  528.0
# 24466       Owen     Myers     NaN   NaN    NaN      NaN  948.344  528.0
# 24467       Owen     Myers     NaN   NaN    NaN      NaN  948.884  540.0
# 24468       Owen     Myers     NaN   NaN    NaN      NaN  949.424  540.0
#
#           VO2_y  power_y
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# ...         ...      ...
# 24464  0.507071      0.0
# 24465  0.507071      0.0
# 24466  0.507071      0.0
# 24467  0.507071      0.0
# 24468  0.507071      0.0
#
# [24469 rows x 19 columns]

# %%
merged_df = merged_df.merge(data_Fencing, on='ID', how='left' )

# %%
merged_df
# Out:
#        ID  age  Weight  Height  P_vt1  P_vt2      sport  Gender Ethnicity  \
# 0       1   15    53.7     161     50    140    fencing  Female   African
# 1       1   15    53.7     161     50    140    fencing  Female   African
# 2       1   15    53.7     161     50    140    fencing  Female   African
# 3       1   15    53.7     161     50    140    fencing  Female   African
# 4       1   15    53.7     161     50    140    fencing  Female   African
# ...    ..  ...     ...     ...    ...    ...        ...     ...       ...
# 52057  18   12    39.7     158     65    168  triathlon    Male    Latino
# 52058  18   12    39.7     158     65    168  triathlon    Male    Latino
# 52059  18   12    39.7     158     65    168  triathlon    Male    Latino
# 52060  18   12    39.7     158     65    168  triathlon    Male    Latino
# 52061  18   12    39.7     158     65    168  triathlon    Male    Latino
#
#       First Name  ... VO2_x  power_x   time_y   RR_y     VO2_y  power_y  \
# 0         Olivia  ...   NaN      NaN      NaN    NaN       NaN      NaN
# 1         Olivia  ...   NaN      NaN      NaN    NaN       NaN      NaN
# 2         Olivia  ...   NaN      NaN      NaN    NaN       NaN      NaN
# 3         Olivia  ...   NaN      NaN      NaN    NaN       NaN      NaN
# 4         Olivia  ...   NaN      NaN      NaN    NaN       NaN      NaN
# ...          ...  ...   ...      ...      ...    ...       ...      ...
# 52057       Owen  ...   NaN      NaN  947.288  536.0  0.507071      0.0
# 52058       Owen  ...   NaN      NaN  947.816  528.0  0.507071      0.0
# 52059       Owen  ...   NaN      NaN  948.344  528.0  0.507071      0.0
# 52060       Owen  ...   NaN      NaN  948.884  540.0  0.507071      0.0
# 52061       Owen  ...   NaN      NaN  949.424  540.0  0.507071      0.0
#
#           time     RR       VO2  power
# 0     -130.840  672.0  0.302008    0.0
# 1     -130.168  672.0  0.302008    0.0
# 2     -129.536  632.0  0.301336    0.0
# 3     -128.824  712.0  0.301336    0.0
# 4     -127.948  876.0  0.301336    0.0
# ...        ...    ...       ...    ...
# 52057      NaN    NaN       NaN    NaN
# 52058      NaN    NaN       NaN    NaN
# 52059      NaN    NaN       NaN    NaN
# 52060      NaN    NaN       NaN    NaN
# 52061      NaN    NaN       NaN    NaN
#
# [52062 rows x 23 columns]

# %%
# Select the required columns
columns_to_keep = ['ID', 'time', 'power', 'RR', 'VO2']

# %%
final_df = merged_df[columns_to_keep]

# %%
final_df
# Out:
#        ID     time  power     RR       VO2
# 0       1 -130.840    0.0  672.0  0.302008
# 1       1 -130.168    0.0  672.0  0.302008
# 2       1 -129.536    0.0  632.0  0.301336
# 3       1 -128.824    0.0  712.0  0.301336
# 4       1 -127.948    0.0  876.0  0.301336
# ...    ..      ...    ...    ...       ...
# 52057  18      NaN    NaN    NaN       NaN
# 52058  18      NaN    NaN    NaN       NaN
# 52059  18      NaN    NaN    NaN       NaN
# 52060  18      NaN    NaN    NaN       NaN
# 52061  18      NaN    NaN    NaN       NaN
#
# [52062 rows x 5 columns]

# %%
output_file = 'merged_athletes_data.xlsx'
final_df.to_excel(output_file, index=False)
